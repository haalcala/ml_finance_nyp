# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Understanding the Jupyter Environment

# %%
print("This is getting the output to console")
# Out:
# This is getting the output to console

# %%
# Using Python as calculator
1 + 6 + 9 * 2 / 4 ** 3
# Out:
# 7.28125

# %%
print(1 + 9)
# Out:
# 10

# %%
# storing values into variable 
variable = 50

# %%
# storing values into variable allows you to recall later
variable
# Out:
# 50

# %%
# and manipulate the value as wlel
variable + 20
# Out:
# 70

# %% [markdown]
# This is a markdown cell. You can **bold** and *italicise* your text. You can also write math formulae as well:
#
# $y = mX + c$
#
#
# $Q(w) = \frac{1}{n}\sum^n_{i=1}Q_i(w)$

# %% [markdown]
# ## Input / Output
# ## Getting Information for Analysis

# %% [markdown]
# We will work with the [iris dataset](https://archive.ics.uci.edu/ml/datasets/iris). The data can be downloaded from the UCI Machine Learning Repository.
#
#
# The data is stored in `iris.data`. To access it, we make use of `Pandas` library. However, before we can make use of Pandas, we need to import the library first. We will import other relevant libraries that we will make use of as well.

# %% [markdown]
# ## Python Scientific Stack

# %% [markdown]
# * [Numpy](http://www.numpy.org/) - Numerical Computation Library
# * [Jupyter Notebook](http://jupyter.org/) - Rich Interactive Interface for reproducible research
# * [Pandas](https://pandas.pydata.org/) - Data Analysis
# * [Matplotlib](https://matplotlib.org/) - Plotting Package
# * [Scipy](https://www.scipy.org/) - Scientific Computing
# * [Scikit-Learn](http://scikit-learn.org/) - Machine Learning
# * [Tensorflow](https://www.tensorflow.org/) - Deep Learning Framework supported by Google
# * [PyTorch](https://pytorch.org/) - Deep Learning Framework supported by Facebook
# * Many more

# %%
import pandas as pd    # Import Pandas
import numpy as np     # Import Numpy, 
import seaborn as sns  # Import Seaborn, visualisation library
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %% [markdown]
# download the data and store it in the variable called `df`

# %%
df = pd.read_csv('iris.data')

# %% [markdown]
# Let's review our data using the method **.head()**

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# note that the first row was used as header. We need to change that

# %%
df = pd.read_csv('iris.data', header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# Let's give our columns of data some useful names. You obtain these information from the UCI Machine Learning Repository

# %%
col_name =   ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
df.columns = col_name
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Iris Data from Seaborn

# %% [markdown]
# The dataset is also available from the Seaborn library

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Let's have a look at some descriptive data with the use of **.describe()** method

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# For some meta data information. You can use the **.info()** method

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Next step is to group by the different flower species and have a look at the data size.

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# ## Visualisation

# %%
sns.pairplot(iris, hue="species", size=2.5);
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.hist(edgecolor='black', linewidth=1.2, figsize=(10,8));
plt.show();

# %%
plt.figure(figsize=(12,8));
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=iris);

# %%
iris.boxplot(by='species', figsize=(12,8));

# %%
sns.pairplot(iris, hue="species", diag_kind="kde");

# %% [markdown]
# ***
